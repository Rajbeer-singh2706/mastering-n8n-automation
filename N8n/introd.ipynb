# %%
###

# %%
## MODULE
##  The AI Automation Revolution: Landscape OPppotunity, and the nocode future
## Large Lanuge Models(LLMs)
# AI Agents and Autonoise 
# Integration platform like n8n

# %%
### Section 3: n8n Setup & Interface 
## n8n Installation & Setup
## n8n Interface Mastery
## n8n Canvas 
## Automation  vs AI Automation vs Agents

# %%
### I want to record the screen and geneate notes which i m writing 
## Aur the steps whhich is being done in the video 

### For example 
## 1. I m watching a video on any platform like EMR steps 
## 2. I want to automate or create a solutioun wheeter it reads the video and generate notes


#### Automation 2 :: 
## Geneate the codebase for me based on the requirements
