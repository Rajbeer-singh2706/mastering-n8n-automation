# %%
## n8n Canvas
'''
 * look into n8n  docs
 * loointo markdown docs
  * n8n shortcut
 * Add notes on canvas
'''


### shortcut 
# Press 1 : to be in center 
#

# %%
### Create your first workflow

# %%
## TEminology
# 1. Node :  A node is a single task within a workflow. Each node represents a specific action or operation that can be performed, such as sending an 
# email, making an API request, or manipulating data.
